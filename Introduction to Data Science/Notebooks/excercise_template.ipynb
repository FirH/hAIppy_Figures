# %% [markdown]
# Gunakan notebook berikut untuk memodifikasi data sesuai dengan instruksi masing masing soal. Setelah mengerjakan soal pertama, gunakan data yang telah diproses untuk memgerjakan soal kedua hingga selesai!

# %%
import pandas as pd
df = pd.read_csv('house assignment.csv')

# %% [markdown]
# # 1. Preprocessing

# %%
# Your code here

# %%
# Submission Cell - Assignment 1: Preprocessing
# Expected columns: id,date,price,bedrooms,bathrooms,sqft_living,sqft_lot,floors,
#                   waterfront,view,condition,grade,sqft_above,sqft_basement,
#                   yr_built,yr_renovated,zipcode,lat,long,sqft_living15,sqft_lot15,
#                   sqft_yard,house_age,basement_ratio

submission_1_cols = [
    'id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
    'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
    'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
    'sqft_living15', 'sqft_lot15', 'sqft_yard', 'house_age', 'basement_ratio'
]

submission_1 = df[submission_1_cols]
submission_1.to_csv('submission_1.csv', index=False)
print("Submission 1 saved!")

# %% [markdown]
# # 2. Rennovated House Data Grouping

# %%
# Your code here

# %%
# Submission Cell - Assignment 2: Renovated House Data Grouping
# Expected columns: id,date,price,bedrooms,bathrooms,sqft_living,sqft_lot,floors,
#                   waterfront,view,condition,grade,sqft_above,sqft_basement,
#                   yr_built,yr_renovated,zipcode,lat,long,sqft_living15,sqft_lot15,
#                   sqft_yard,house_age,basement_ratio

submission_2_cols = [
    'id', 'date', 'price', 'bedrooms', 'bathrooms', 'sqft_living', 'sqft_lot',
    'floors', 'waterfront', 'view', 'condition', 'grade', 'sqft_above',
    'sqft_basement', 'yr_built', 'yr_renovated', 'zipcode', 'lat', 'long',
    'sqft_living15', 'sqft_lot15', 'sqft_yard', 'house_age', 'basement_ratio'
]

submission_2 = df[submission_2_cols]
submission_2.to_csv('submission_2.csv', index=False)
print("Submission 2 saved!")

# %% [markdown]
# # 3. Statistics

# %%
# Your code here

# %%
# Submission Cell - Assignment 3: Statistics
# Expected format: id,answer
# id 0 -> price mean, id 1 -> price median, id 2 -> condition mode

submission_3 = pd.DataFrame({
    'id': [0, 1, 2],
    'answer': [
        # isi dengan mean price,
        # isi dengan median price,
        # isi dengan mode of condition
    ]
})

submission_3.to_csv('submission_3.csv', index=False)
print("Submission 3 saved!")

# %% [markdown]
# # 4. Feature Engineering

# %%
# Your code here

# %%
# Submission Cell - Assignment 4: Feature Engineering
# Expected columns: id, sqft_yard, house_age, basement_ratio

submission_4 = df[['id', 'sqft_yard', 'house_age', 'basement_ratio']]
submission_4.to_csv('submission_4.csv', index=False)
print("Submission 4 saved!")
